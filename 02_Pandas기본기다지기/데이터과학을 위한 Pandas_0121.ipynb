# %% [markdown]
# ## Google Colab 사용 방법
#
# - 방향키 ↑↓: 셀 간 이동
# - Enter: 편집모드
# - Ctrl + Enter: 셀 실행
# - Shift + Enter: 셀 실행 + 다음 셀 선택
#
# ---
#
# - Ctrl +M D: 셀 삭제
# - Ctrl + M K: 셀 위로 이동
# - Ctrl + M J: 셀 아래로 이동

# %% [markdown]
# ![alt text](https://hackernoon.com/hn-images/0*Xhz01Vby2rg86xZj)

# %% [markdown]
# # 1. Pandas
#
# Pandas는 다음과 같은 특징을 같습니다.
# - NumPy를 내부적으로 활용함(NumPy의 특징을 그대로 가짐)
# - 데이터분석에 특화된 데이터 구조 제공
# - 다양한 데이터 분석 함수 제공
# - 데이터베이스에 쉽게 연결 가능
#
# ## Cheat Sheet
#
# 판다스는 많은 기능을 제공합니다. 이번 강의에서는 이러한 기능들을 학습할 예정입니다.</br>
# 그러나 이 모든 기능을 외울 순 없습니다. 외울 필요도 없고요.
#
# **아래는 판다스를 한 장에 정리해 둔 치트시트입니다**
#
# 어떠한 기능들을 하는 함수들이 있다는것만 학습한 뒤 해당 기능이 필요할 때 아래의 치트시트를 참조해가며 판다스를 사용하면 됩니다.

# %% [markdown]
# ![](http://drive.google.com/uc?export=view&id=12qAWxrdhFmdYN61uYbqM58jHm1y9PWJ3)

# %% [markdown]
# 파이썬에서 pandas를 사용할 때는 일반적으로 다음과 같이 pd형태로 임포트해서 사용합니다

# %%
import pandas as pd

# %%
# numpy와 matplotlib 임포트
# %matplotlib inline # 노트북에서 그래프를 보여주기 위해 추가해주는 코드
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Pandas의 모든 API는 help 함수를 이용하여 도움말을 확인할 수 있습니다.

# %%
# help(pd)
# help(pd.read_csv)
help(pd.DataFrame)
# pd.DataFrame?

# %% [markdown]
# # 2. Pandas 데이터 구조

# %% [markdown]
# ![](http://drive.google.com/uc?export=view&id=1B0ZpHC2hCXfoeYKxMT4DRHqKrQbEbztj)
#
# ## Series
# - 1차원 데이터 구조
# - 일반적으로 s 또는 sr로 이름 붙임
#
# ![](http://drive.google.com/uc?export=view&id=1msqZqjnrFLJXlaBGF7DsLf2B0_lA_J07)
#
# Series는 **pd.Series()** 로 생성합니다.

# %%
s = pd.Series([3, -5, 7, 4]) # 인덱스 없이 생성

# %%
s
# Out:
# 0    3
# 1   -5
# 2    7
# 3    4
# dtype: int64

# %% [markdown]
# 인덱스를 특별히 지정해주지 않으면 NumPy 다차원배열처럼 0부터 인덱스가 시작됩니다.
#
# NumPy 다차원 배열과 다르게 Pandas Series는 인덱스를 지정해 줄 수 있으며 숫자가 아닌 문자열도 인덱스가 될 수 있습니다.

# %%
s = pd.Series([3, -5, 7, 4], index=['a', 'b', 'c', 'd'])

# %%
s
# Out:
# a    3
# b   -5
# c    7
# d    4
# dtype: int64

# %% [markdown]
# **type()**을 통해 데이터타입이 Series인 걸 확인할 수 있습니다.

# %%
type(s)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### 속성

# %% [markdown]
# Series는 index와 values를 가집니다.

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
s.values
# Out:
# array([ 3, -5,  7,  4])

# %% [markdown]
# ### 인덱싱

# %% [markdown]
# Series는 요소는 index명 또는 index의 순서를 통해 인덱싱할 수 있습니다.

# %%
# index명으로 조회
s['a']
# Out:
# 3

# %%
# index순서로 조회
s[2]
# Out:
# 7

# %% [markdown]
# ### 파이썬 딕셔너리와 Pandas Series의 공통점, 차이점

# %% [markdown]
# Index와 value를 가진다는 점에서 key와 value를 가지는 파이썬 딕셔너리와 유사하다 볼 수 있습니다.
#
# 그렇기에 파이썬 딕셔너리를 통해 Series를 생성할 수 있습니다.

# %%
# pop_dict는 파이썬 딕셔너리
pop_dict = {'Germany': 81.3, 
            'Belgium': 11.3, 
            'France': 64.3, 
            'United Kingdom': 64.9, 
            'Netherlands': 16.9}

# pop_dict로 Series 생성
population = pd.Series(pop_dict)
population
# Out:
# Germany           81.3
# Belgium           11.3
# France            64.3
# United Kingdom    64.9
# Netherlands       16.9
# dtype: float64

# %% [markdown]
# 딕셔너리에서 key값을 이용해 value를 조회하듯 Series에서 index를 이용해 value를 조회할 수 있습니다.

# %%
pop_dict['France']
# Out:
# 64.3

# %%
population['France']
# Out:
# 64.3

# %% [markdown]
# 딕셔너리와 Series의 차이점은, 딕셔너리의 Key는 순서가 없고 pandas Series의 index는 순서가 있다는 점입니다.
# 그렇기에 Series는 index의 순서를 통해서도 value 조회가 가능합니다.

# %%
# KeyError 발생(2라는 Key 값은 없음)
pop_dict[2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-acf7040711f3> in <module>()
#       1 # KeyError 발생(2라는 Key 값은 없음)
# ----> 2 pop_dict[2]
#
# KeyError: 2

# %%
pop_dict['France']
# Out:
# 64.3

# %%
population[2]
# Out:
# 64.3

# %% [markdown]
# 또한 Series는 딕셔너리와 다르게 아래와 같은 연산이 가능합니다.

# %%
population*1000
# Out:
# Germany           81300.0
# Belgium           11300.0
# France            64300.0
# United Kingdom    64900.0
# Netherlands       16900.0
# dtype: float64

# %%
# TypeError발생 (dict * int)
pop_dict * 1000
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-233968de5c1f> in <module>()
#       1 # TypeError발생 (dict * int)
# ----> 2 pop_dict * 1000
#
# TypeError: unsupported operand type(s) for *: 'dict' and 'int'

# %% [markdown]
# ## 참고. Index가 문자열에 저장된 숫자일 경우
#
# Series의 요소를 조회하는데 혼돈이 올 수 있으니 숫자 Index를 원할 경우,
# - 문자가 아닌 정수형으로 index를 지정합시다.
# - 1이 아닌 0부터 index를 지정합시다.

# %%
sr = pd.Series([1, 2, 3, 4], index=['1', '2', '3', '4'])

# %%
# index명으로 접근
sr['1']
# Out:
# 1

# %%
# index순서로 접근
sr[1]
# Out:
# 2

# %% [markdown]
# DataFrame에서도 마찬가지로 숫자 Index를 사용할 경우 염두해두어야 합니다.

# %% [markdown]
# ## DataFrame
# - 2차원 데이터 구조
# - 일반적으로 df로 이름 붙임
# - 엑셀 스프레드시트, 데이터베이스등과 동일한 2차원 구조
# - 가장 많이 활용하게될 구조
# - Series가 합쳐진 형태
#
# ![](http://drive.google.com/uc?export=view&id=1lixriaQy119N0nNM0e_TTQ1DfuSNMk76)
#
# DataFrame은 **pd.DataFrame()** 으로 생성합니다.

# %% [markdown]
# 중첩된 리스트나 딕셔너리를 통해 DataFrame을 생성할 수 있습니다.

# %%
# 중첩된 리스트를 통한 데이터 생성
# 각 행을 리스트로 만들어야 함
data = [['Belgium', 'Brussels', 11190846],
        ['India', 'New Delhi', 1303171035],
        ['Brazil', 'Brasília', 207847528]]

df = pd.DataFrame(data)

df
# Out:
#          0          1           2
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasília   207847528

# %% [markdown]
# columns 파라메터를 통해 칼럼명 역시 정해줄 수 있습니다.

# %%
# 중첩된 리스트를 통한 데이터 생성
# 각 행을 리스트로 만들어야 함
data = [['Belgium', 'Brussels', 11190846],
        ['India', 'New Delhi', 1303171035],
        ['Brazil', 'Brasília', 207847528]]

df = pd.DataFrame(data, columns=['Country', 'Capital', 'Population'])

df
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasília   207847528

# %% [markdown]
# 데이터프레임의 데이터는 딕셔너리로 넘겨주는게 일반적입니다.
#
# - 칼럼명을 함께 넘겨줄 수 있기 때문입니다.
# - **동일한 데이터타입끼리 함께 묶어서 넘겨줄 수 있기 때문입니다.**

# %%
data = {'Country': ['Belgium', 'India', 'Brazil'],
        'Capital': ['Brussels', 'New Delhi', 'Brasília'],
        'Population': [11190846, 1303171035, 207847528]}

df = pd.DataFrame(data)

df
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasília   207847528

# %% [markdown]
# 칼럼명과 마찬가지로 인덱스 역시 변경할 수 있습니다.

# %%
data = {'Country': ['Belgium', 'India', 'Brazil'],
        'Capital': ['Brussels', 'New Delhi', 'Brasília'],
        'Population': [11190846, 1303171035, 207847528]}

df_2 = pd.DataFrame(data,
                    index=['aa', 'bb', 'cc'])

df_2
# Out:
#     Country    Capital  Population
# aa  Belgium   Brussels    11190846
# bb    India  New Delhi  1303171035
# cc   Brazil   Brasília   207847528

# %% [markdown]
# **type()**을 통해 데이터타입이 DataFrame인 걸 확인할 수 있습니다.

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# 데이터프레임의 하나의 열은 어떤 데이터구조로 되어있을까요?

# %%
type(df['Country'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# 데이터프레임 각 열의 데이터타입은 Series라는걸 알 수 있습니다.

# %% [markdown]
# ### 속성
#
# 아래와 같은 속성을 가집니다.
#
# - index
# - columns
# - dtypes
# - values

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['Country', 'Capital', 'Population'], dtype='object')

# %%
df.dtypes
# Out:
# Country       object
# Capital       object
# Population     int64
# dtype: object

# %%
df.values
# Out:
# array([['Belgium', 'Brussels', 11190846],
#        ['India', 'New Delhi', 1303171035],
#        ['Brazil', 'Brasília', 207847528]], dtype=object)

# %% [markdown]
# Index, columns, dtypes를 한번에 조회하고 싶다면 info()를 사용하세요.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     3 non-null      object
#  1   Capital     3 non-null      object
#  2   Population  3 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 200.0+ bytes

# %%
df.describe()
# Out:
#          Population
# count  3.000000e+00
# mean   5.074031e+08
# std    6.961346e+08
# min    1.119085e+07
# 25%    1.095192e+08
# 50%    2.078475e+08
# 75%    7.555093e+08
# max    1.303171e+09

# %% [markdown]
# 특정한 칼럼을 index로 사용할수도 있습니다.

# %%
df
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasília   207847528

# %%
df_index_with_country = df.set_index('Country')

df_index_with_country
# Out:
#            Capital  Population
# Country
# Belgium   Brussels    11190846
# India    New Delhi  1303171035
# Brazil    Brasília   207847528

# %% [markdown]
# 하나의 인덱스만 가능한것은 아닙니다. DataFrame은 여러개의 인덱스를 가질 수 있습니다.

# %%
df_index_with_country_and_capital = df.set_index(['Country', 'Capital'])

df_index_with_country_and_capital
# Out:
#                    Population
# Country Capital
# Belgium Brussels     11190846
# India   New Delhi  1303171035
# Brazil  Brasília    207847528

# %%
# 인덱싱
df_index_with_country_and_capital.loc[['Brazil', 'Brasília']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-0af68fa70424> in <module>()
#       1 # 인덱싱
# ----> 2 df_index_with_country_and_capital.loc[['Brazil', 'Brasília']]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1097                     raise ValueError("Cannot index with multidimensional key")
#    1098
# -> 1099                 return self._getitem_iterable(key, axis=axis)
#    1100
#    1101             # nested tuple slicing
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1035
#    1036         # A collection of keys
# -> 1037         keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1038         return self.obj._reindex_with_indexers(
#    1039             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1238         # Have the index compute an indexer or return None
#    1239         # if it cannot handle:
# -> 1240         indexer, keyarr = ax._convert_listlike_indexer(key)
#    1241         # We only act on all found values:
#    1242         if indexer is not None and (indexer != -1).all():
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/multi.py in _convert_listlike_indexer(self, keyarr)
#    2398             mask = check == -1
#    2399             if mask.any():
# -> 2400                 raise KeyError(f"{keyarr[mask]} not in index")
#    2401
#    2402         return indexer, keyarr
#
# KeyError: "['Brasília'] not in index"

# %% [markdown]
# ### Dataframe의 column은 어떤 데이터타입일까
#
# 기존에 학습한 데이터프레임 생성 방식은 아래처럼 모든 데이터를 직접 명시해주는 것이었습니다.
#
# 아래 코드는 각 열을 파이썬의 리스트 형태로 입력하는 방식입니다.
# 리스트 형태로 입력된 데이터를 기반으로 판다스가 Series를 만들고 Series들로 DataFrame을 만드는 것이죠.

# %%
data = {'col1': [1, 2, 3, 4],
        'col2': [5, 6, 7, 8],
        'col3': [9, 10, 11, 12]}

df_3 = pd.DataFrame(data, 
                    index=['A', 'B', 'C', 'D'])

df_3
# Out:
#    col1  col2  col3
# A     1     5     9
# B     2     6    10
# C     3     7    11
# D     4     8    12

# %% [markdown]
# ![](http://drive.google.com/uc?export=view&id=1vXLOGcypyLgT12DGNIGTnmna8BIW1pvK)

# %% [markdown]
# 파이썬 리스트가 아닌 Series를 통해서도 DataFrame을 생성할 수 있습니다.

# %%
s_1 = pd.Series([1, 2, 3, 4], index=['A', 'B', 'C', 'D'])
s_2 = pd.Series([5, 6, 7, 8], index=['A', 'B', 'C', 'D'])
s_3 = pd.Series([9, 10, 11, 12], index=['A', 'B', 'C', 'D'])

data = {'col1': s_1,
        'col2': s_2,
        'col3': s_3}

df_4 = pd.DataFrame(data, index=['A', 'B', 'C', 'D'])

df_4
# Out:
#    col1  col2  col3
# A     1     5     9
# B     2     6    10
# C     3     7    11
# D     4     8    12

# %% [markdown]
# ## NumPy ndarray와 비교

# %% [markdown]
# ### 공통점
#
# NumPy 다차원배열처럼 많은 연산들이 요소들간에 이루어집니다.(Elementwise-operation)

# %%
s
# Out:
# a    3
# b   -5
# c    7
# d    4
# dtype: int64

# %%
s + 10
# Out:
# a    13
# b     5
# c    17
# d    14
# dtype: int64

# %%
df
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasília   207847528

# %%
df['Population'] / 1000
# Out:
# 0      11190.846
# 1    1303171.035
# 2     207847.528
# Name: Population, dtype: float64

# %%
df['Country'] + df['Capital']
# Out:
# 0    BelgiumBrussels
# 1     IndiaNew Delhi
# 2     BrazilBrasília
# dtype: object

# %% [markdown]
# ### 차이점
#
# Series간 연산을 하는 경우, index를 기반으로 이루어집니다.
#
# (모든 NumPy 다차원배열은 shape가 동일하다면 index도 동일하기에 index가 달라 연산이 이루어지지 않는 경우는 없음.)

# %%
s
# Out:
# a    3
# b   -5
# c    7
# d    4
# dtype: int64

# %%
s1 = s[['a', 'b']]
s2 = s[['b', 'c']]

# %%
s1
# Out:
# a    3
# b   -5
# dtype: int64

# %%
s2
# Out:
# b   -5
# c    7
# dtype: int64

# %%
s1 + s2
# Out:
# a     NaN
# b   -10.0
# c     NaN
# dtype: float64

# %% [markdown]
# ## 실습

# %%
df_index_with_country
# Out:
#            Capital  Population
# Country
# Belgium   Brussels    11190846
# India    New Delhi  1303171035
# Brazil    Brasília   207847528

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: df_index_with_country이 데이터로 주어졌을때 각 국가의 수도 인구는 벨기에 수도 인구 대비 몇 배인지 구하세요.
# </div>

# %%
df_index_with_country['Population'] / df_index_with_country['Population']['Belgium']
# Out:
# Country
# Belgium      1.000000
# India      116.449734
# Brazil      18.572995
# Name: Population, dtype: float64

# %% [markdown]
# # 3. Pandas Importing/Exproting
#
# 직접 데이터를 입력하여 DataFrame이나 Series를 생성할 일은 실무에서 많지 않습니다.<br>
# 실무에서는 이미 데이터가 존재하는 경우가 많고 그 데이터를 판다스로 importing해서 분석을 진행합니다.
#
# CSV나 엑셀 형태의 파일로 저장된 데이터를 판다스로 가져오거나 직접 데이터베이스에 연결해서 데이터를 가져와서 작업하는 경우가 일반적입니다.
#
# pandas가 지원하는 Importing/Exporting 포맷은 아래와 같습니다.
# - csv (모든 text파일 연결에 사용)
# - excel
# - sql (모든 데이터베이스 연결에 사용)
# - hdf5
# - json
# - html
# - pickle
# - ...

# %% [markdown]
# Importing 함수의 경우 **pd.read** 형태를 가지며 Exporting 함수의 경우 **df.to** 형태를 가집니다.
#
#
# 예시) json의 경우

# %%
json_data = df.to_json()
json_data
# Out:
# '{"Country":{"0":"Belgium","1":"India","2":"Brazil"},"Capital":{"0":"Brussels","1":"New Delhi","2":"Bras\\u00edlia"},"Population":{"0":11190846,"1":1303171035,"2":207847528}}'

# %%
pd.read_json(json_data)
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasília   207847528

# %% [markdown]
# ## 1) CSV
#
# 하나의 파일로 관리 가능한 크기의 데이터라면, 데이터를 파일로 저장할때 일반적으로 CSV포맷을 활용합니다.
#
# CSV는 comma-separated values의 약자이며 값들을 ,로 구분합니다.

# %% [markdown]
# ### Importing

# %%
# 파일다운로드 받기
# !wget -O 'iris_sample.csv' https://raw.githubusercontent.com/duc-ke/edu_jupyter_pandas/master/dataset/iris_sample.csv
# Out:
# --2021-01-20 00:43:57--  https://raw.githubusercontent.com/duc-ke/edu_jupyter_pandas/master/dataset/iris_sample.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 683 [text/plain]
# Saving to: ‘iris_sample.csv’
#
# iris_sample.csv     100%[===================>]     683  --.-KB/s    in 0s
#
# 2021-01-20 00:43:57 (50.4 MB/s) - ‘iris_sample.csv’ saved [683/683]

# %%
df_iris_sample = pd.read_csv('iris_sample.csv')

# %%
df_iris_sample
# Out:
#     sepal_length  sepal_width  petal_length  petal_width    species
# 0            5.1          3.5           1.4          0.2     setosa
# 1            4.9          3.0           1.4          0.2     setosa
# 2            4.7          3.2           1.3          0.2     setosa
# 3            4.6          3.1           1.5          0.2     setosa
# 4            5.0          3.6           1.4          0.2     setosa
# 5            5.4          3.9           1.7          0.4     setosa
# 6            4.6          3.4           1.4          0.3     setosa
# 7            5.0          3.4           1.5          0.2     setosa
# 8            4.4          2.9           1.4          0.2     setosa
# 9            4.9          3.1           1.5          0.1     setosa
# 10           5.4          3.7           1.5          0.2     setosa
# 11           4.8          3.4           1.6          0.2     setosa
# 12           4.8          3.0           NaN          0.1     setosa
# 13           4.3          3.0           1.1          0.1  virginica
# 14           5.8          4.0           NaN          0.2  virginica
# 15           5.7          NaN           1.5          0.4  virginica
# 16           5.4          3.9           1.3          0.4  virginica
# 17           5.1          3.5           NaN          0.3  virginica
# 18           5.7          3.8           1.7          0.3  virginica
# 19           5.1          3.8           1.5          0.3  virginica
# 20           5.1          3.5           1.4          0.2     setosa
# 21           4.9          3.0           1.4          0.2     setosa
# 22           4.7          3.2           1.3          0.2     setosa
# 23           5.1          3.5           1.4          0.2  virginica
# 24           4.9          3.0           1.4          0.2  virginica
# 25           4.7          3.2           1.3          0.2  virginica

# %% [markdown]
# csv뿐만 아니라 tsv, txt도 read_csv()파일을 통해 읽어올 수 있습니다.
#
# 파일 관점에서 보면 csv, tsv, txt는 동일합니다. csv, tsv역시 txt파일이며 값을 구분하는 구분자가 콤마냐 탭이냐의 차이입니다.

# %% [markdown]
# #### txt

# %%
# 'iris_sample.txt' 로 확장자를 바꿔 파일다운로드 받기
# !wget -O 'iris_sample.txt' https://raw.githubusercontent.com/duc-ke/edu_jupyter_pandas/master/dataset/iris_sample.csv
# Out:
# --2021-01-20 00:49:27--  https://raw.githubusercontent.com/duc-ke/edu_jupyter_pandas/master/dataset/iris_sample.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 683 [text/plain]
# Saving to: ‘iris_sample.txt’
#
# iris_sample.txt     100%[===================>]     683  --.-KB/s    in 0s
#
# 2021-01-20 00:49:28 (27.8 MB/s) - ‘iris_sample.txt’ saved [683/683]

# %%
pd.read_csv('iris_sample.txt')
# Out:
#     sepal_length  sepal_width  petal_length  petal_width    species
# 0            5.1          3.5           1.4          0.2     setosa
# 1            4.9          3.0           1.4          0.2     setosa
# 2            4.7          3.2           1.3          0.2     setosa
# 3            4.6          3.1           1.5          0.2     setosa
# 4            5.0          3.6           1.4          0.2     setosa
# 5            5.4          3.9           1.7          0.4     setosa
# 6            4.6          3.4           1.4          0.3     setosa
# 7            5.0          3.4           1.5          0.2     setosa
# 8            4.4          2.9           1.4          0.2     setosa
# 9            4.9          3.1           1.5          0.1     setosa
# 10           5.4          3.7           1.5          0.2     setosa
# 11           4.8          3.4           1.6          0.2     setosa
# 12           4.8          3.0           NaN          0.1     setosa
# 13           4.3          3.0           1.1          0.1  virginica
# 14           5.8          4.0           NaN          0.2  virginica
# 15           5.7          NaN           1.5          0.4  virginica
# 16           5.4          3.9           1.3          0.4  virginica
# 17           5.1          3.5           NaN          0.3  virginica
# 18           5.7          3.8           1.7          0.3  virginica
# 19           5.1          3.8           1.5          0.3  virginica
# 20           5.1          3.5           1.4          0.2     setosa
# 21           4.9          3.0           1.4          0.2     setosa
# 22           4.7          3.2           1.3          0.2     setosa
# 23           5.1          3.5           1.4          0.2  virginica
# 24           4.9          3.0           1.4          0.2  virginica
# 25           4.7          3.2           1.3          0.2  virginica

# %% [markdown]
# #### tsv
#
# TSV는 tab-separated values의 약자이며 값들을 tab으로 구분합니다.

# %%
# !wget -O 'tsv_sample.tsv' https://gist.githubusercontent.com/mbostock/3305937/raw/a5be7c5fd55c4fa0ca8a400cb68d658a40989966/data.tsv
# Out:
# --2021-01-20 00:49:28--  https://gist.githubusercontent.com/mbostock/3305937/raw/a5be7c5fd55c4fa0ca8a400cb68d658a40989966/data.tsv
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33 [text/plain]
# Saving to: ‘tsv_sample.tsv’
#
# tsv_sample.tsv      100%[===================>]      33  --.-KB/s    in 0s
#
# 2021-01-20 00:49:28 (2.24 MB/s) - ‘tsv_sample.tsv’ saved [33/33]

# %%
pd.read_csv('tsv_sample.tsv')
# Out:
#      x\ty
# 0   5\t90
# 1  25\t30
# 2  45\t50
# 3  65\t55
# 4  85\t25

# %%
pd.read_csv('tsv_sample.tsv', sep='\t')
# Out:
#     x   y
# 0   5  90
# 1  25  30
# 2  45  50
# 3  65  55
# 4  85  25

# %% [markdown]
# ### Exporting
# csv를 통해 생성한 df_iris_sample에서 첫 5행만 'iris_sample_2.csv'로 저장해봅시다

# %%
df_iris_sample.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
df_iris_sample_2 = df_iris_sample.head()

# %%
df_iris_sample_2
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df_iris_sample_2.to_csv('iris_sample_2.csv')

# %% [markdown]
# 잘 저장되었는지 다시 확인해보겠습니다.

# %%
pd.read_csv('iris_sample_2.csv')
# Out:
#    Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width species
# 0           0           5.1          3.5           1.4          0.2  setosa
# 1           1           4.9          3.0           1.4          0.2  setosa
# 2           2           4.7          3.2           1.3          0.2  setosa
# 3           3           4.6          3.1           1.5          0.2  setosa
# 4           4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# **Unnamed: 0** 라는 열이 들어가 있습니다. 이는 to_csv()시 index도 함께 파일에 저장되기에 생기는 문제입니다.
#
# 저장시 index=False 를 통해 이 문제를 해결할 수 있습니다.

# %%
df_iris_sample_2.to_csv('iris_sample_2_no_index.csv', index=False)

# %%
pd.read_csv('iris_sample_2_no_index.csv')
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# txt, tsv도 동일한 to_csv()로 다룰 수 있습니다.

# %% [markdown]
# ## 2) 엑셀
#
# 엑셀파일은 read_excel(), to_excel() 을 활용해서 다룹니다.

# %% [markdown]
# ### 입력

# %%
# 파일다운로드 받기
# !wget -O '성적표.xlsx' https://www.dropbox.com/s/zubhmxf4aj9eg7y/%EC%84%B1%EC%A0%81%ED%91%9C.xlsx?dl=0
# Out:
# --2021-01-20 01:03:49--  https://www.dropbox.com/s/zubhmxf4aj9eg7y/%EC%84%B1%EC%A0%81%ED%91%9C.xlsx?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.18, 2620:100:6016:18::a27d:112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/zubhmxf4aj9eg7y/%EC%84%B1%EC%A0%81%ED%91%9C.xlsx [following]
# --2021-01-20 01:03:49--  https://www.dropbox.com/s/raw/zubhmxf4aj9eg7y/%EC%84%B1%EC%A0%81%ED%91%9C.xlsx
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucc9250ea07bb318e9c30d573060.dl.dropboxusercontent.com/cd/0/inline/BHXAFy9BtEV_hwdbgxgbp5r0VMy-U5AczjdrLsThBJspDLCuBgugqIY7x3jVEacuhz3GW0ZDJeuqAx93-bwjh2-7xxMqV7weIWYgkOWDHYGfeFfnVExIrvth80K464jjZ5s/file# [following]
# --2021-01-20 01:03:49--  https://ucc9250ea07bb318e9c30d573060.dl.dropboxusercontent.com/cd/0/inline/BHXAFy9BtEV_hwdbgxgbp5r0VMy-U5AczjdrLsThBJspDLCuBgugqIY7x3jVEacuhz3GW0ZDJeuqAx93-bwjh2-7xxMqV7weIWYgkOWDHYGfeFfnVExIrvth80K464jjZ5s/file
# Resolving ucc9250ea07bb318e9c30d573060.dl.dropboxusercontent.com (ucc9250ea07bb318e9c30d573060.dl.dropboxusercontent.com)... 162.125.1.15, 2620:100:6016:15::a27d:10f
# Connecting to ucc9250ea07bb318e9c30d573060.dl.dropboxusercontent.com (ucc9250ea07bb318e9c30d573060.dl.dropboxusercontent.com)|162.125.1.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/BHWcj0_MxImlrkKbvkudJRWOI_Uh8HYowwhRyaK28-rri-Yn03U62DabHCaq01OFQo_-AKRtP9e8y2rxGg9qXmfI7QMP77XoXXIoJlUI8ciPDAJb_we1E6gsCJ3Di_jKNdAb7Srrjd1CCj9JgtKpzVu2LUJYVZY_evsiDeGF8NBi6YX3vYKmeJCI40f_07RYO2KkV0Y36gtVKOhFrbIM_BQK0c3QB4vcf7qvlyqJ8fsBEaMTkf9ap8Nq2HYI70I-gqdkBQD4JWBNq88FsWhxsHRwrdrxcFiq7geBBq9YXUOMrfQRIGXChipUOnuxdktSqYt7wRO6PQxsMe7Tc-c5R8LIcxzitziqB0lJxw_HPNL9gQ/file [following]
# --2021-01-20 01:03:50--  https://ucc9250ea07bb318e9c30d573060.dl.dropboxusercontent.com/cd/0/inline2/BHWcj0_MxImlrkKbvkudJRWOI_Uh8HYowwhRyaK28-rri-Yn03U62DabHCaq01OFQo_-AKRtP9e8y2rxGg9qXmfI7QMP77XoXXIoJlUI8ciPDAJb_we1E6gsCJ3Di_jKNdAb7Srrjd1CCj9JgtKpzVu2LUJYVZY_evsiDeGF8NBi6YX3vYKmeJCI40f_07RYO2KkV0Y36gtVKOhFrbIM_BQK0c3QB4vcf7qvlyqJ8fsBEaMTkf9ap8Nq2HYI70I-gqdkBQD4JWBNq88FsWhxsHRwrdrxcFiq7geBBq9YXUOMrfQRIGXChipUOnuxdktSqYt7wRO6PQxsMe7Tc-c5R8LIcxzitziqB0lJxw_HPNL9gQ/file
# Reusing existing connection to ucc9250ea07bb318e9c30d573060.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10921 (11K) [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘성적표.xlsx’
#
# 성적표.xlsx         100%[===================>]  10.67K  --.-KB/s    in 0s
#
# 2021-01-20 01:03:50 (50.1 MB/s) - ‘성적표.xlsx’ saved [10921/10921]

# %%
pd.read_excel('성적표.xlsx')
# Out:
#     반 이름    국   영   수   과
# 0   1  A   67  87  90  98
# 1   1  B   45  45  56  98
# 2   1  C   95  59  96  88
# 3   1  D   65  94  89  98
# 4   1  E   45  65  78  98
# 5   1  F   78  76  98  89
# 6   2  G   87  67  65  56
# 7   2  H   89  98  78  78
# 8   2  I  100  78  56  65
# 9   2  J   99  89  87  87
# 10  2  K   98  45  56  54
# 11  2  L   65  89  87  78

# %% [markdown]
# 기본적으로 read_excel()은 첫번째 시트를 가져옵니다. 위 코드는 sheet_name=0이 생략되어있으며 아래의 코드와 동일한 결과를 보입니다.

# %%
pd.read_excel('성적표.xlsx', sheet_name=0)
# Out:
#     반 이름    국   영   수   과
# 0   1  A   67  87  90  98
# 1   1  B   45  45  56  98
# 2   1  C   95  59  96  88
# 3   1  D   65  94  89  98
# 4   1  E   45  65  78  98
# 5   1  F   78  76  98  89
# 6   2  G   87  67  65  56
# 7   2  H   89  98  78  78
# 8   2  I  100  78  56  65
# 9   2  J   99  89  87  87
# 10  2  K   98  45  56  54
# 11  2  L   65  89  87  78

# %% [markdown]
# 두 번째 시트를 가져오려면 sheet_name 파라메터에 1을 전달해야 합니다.

# %%
pd.read_excel('성적표.xlsx', sheet_name=1)
# Out:
#     반 이름    국   영   수   과
# 0   3  A   67  87  90  98
# 1   3  B   45  45  56  98
# 2   3  C   95  59  96  88
# 3   3  D   65  94  89  98
# 4   3  E   45  65  78  98
# 5   3  F   78  76  98  89
# 6   4  G   87  67  65  56
# 7   4  H   89  98  78  78
# 8   4  I  100  78  56  65
# 9   4  J   99  89  87  87
# 10  4  K   98  45  56  54
# 11  4  L   65  89  87  78

# %% [markdown]
# 또는 시트의 이름을 명시해서 가져올수도 있습니다.

# %%
pd.read_excel('성적표.xlsx', sheet_name='Sheet2')
# Out:
#     반 이름    국   영   수   과
# 0   3  A   67  87  90  98
# 1   3  B   45  45  56  98
# 2   3  C   95  59  96  88
# 3   3  D   65  94  89  98
# 4   3  E   45  65  78  98
# 5   3  F   78  76  98  89
# 6   4  G   87  67  65  56
# 7   4  H   89  98  78  78
# 8   4  I  100  78  56  65
# 9   4  J   99  89  87  87
# 10  4  K   98  45  56  54
# 11  4  L   65  89  87  78

# %% [markdown]
# ### 출력

# %% [markdown]
# to_excel()로 엑셀 파일 쓰기가 가능합니다.
#
# sheet_name 파라메터를 통해 시트명을 정할 수 있습니다.
#
# > to_excel()을 사용하기 위해선 ‘openpyxl’ 또는 ‘xlsxwriter’ 라이브러리가 필요합니다.

# %%
# xlsxwriter 라이브러리 설치
# !pip install xlsxwriter
# Out:
# Collecting xlsxwriter
#   Downloading https://files.pythonhosted.org/packages/6b/41/bf1aae04932d1eaffee1fc5f8b38ca47bbbf07d765129539bc4bcce1ce0c/XlsxWriter-1.3.7-py2.py3-none-any.whl (144kB)
#      |████████████████████████████████| 153kB 7.9MB/s
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-1.3.7

# %%
df_sheet2 = pd.read_excel('성적표.xlsx', sheet_name='Sheet2')

df_sheet2.to_excel('to_excel.xlsx', sheet_name='이름을 적어주세요')
# df_sheet2.to_excel('to_excel.xlsx', sheet_name='이름을 적어주세요', index=False)

# %%
pd.read_excel('to_excel.xlsx')
# Out:
#     Unnamed: 0  반 이름    국   영   수   과
# 0            0  3  A   67  87  90  98
# 1            1  3  B   45  45  56  98
# 2            2  3  C   95  59  96  88
# 3            3  3  D   65  94  89  98
# 4            4  3  E   45  65  78  98
# 5            5  3  F   78  76  98  89
# 6            6  4  G   87  67  65  56
# 7            7  4  H   89  98  78  78
# 8            8  4  I  100  78  56  65
# 9            9  4  J   99  89  87  87
# 10          10  4  K   98  45  56  54
# 11          11  4  L   65  89  87  78

# %% [markdown]
# ## 3) 데이터베이스

# %%
#  라이브러리 설치
# !pip install mysql-connector-python

# %%
import sqlalchemy

user = "anonymous"
host = "ensembldb.ensembl.org"
port = 3337
database = "ailuropoda_melanoleuca_core_79_1"

url = f"mysql+mysqlconnector://{user}@{host}:{port}/{database}"
# url = f"mysql+mysqlconnector://{user}:{password}@{host}:{port}/{database}"

connection = sqlalchemy.create_engine(url)

# %%
pd.read_sql("select * from analysis limit 10", connection)

# %% [markdown]
# # 4. 인덱싱/슬라이싱

# %% [markdown]
# ## 0) [ ]
#
# - **[ ]** 연산자를 활용해 데이터를 가져올 수 있습니다.
# - 간단히 사용하기에는 좋지만 불규칙적이라 loc, iloc를 통한 인덱싱/슬라이싱을 추천합니다.

# %%
df
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasília   207847528

# %% [markdown]
# - 단일 칼럼 조회

# %%
df['Country']
# Out:
# 0    Belgium
# 1      India
# 2     Brazil
# Name: Country, dtype: object

# %% [markdown]
# - 복수 칼럼 조회

# %%
df[['Country', 'Population']]
# Out:
#    Country  Population
# 0  Belgium    11190846
# 1    India  1303171035
# 2   Brazil   207847528

# %% [markdown]
# - 슬라이싱
#   - **[ ]** 를 통한 슬라이싱은 row(행)에 적용됩니다.

# %%
# index 슬라이싱. 2 미포함
df[0:2]
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035

# %% [markdown]
# - 슬라이싱
#   - index로 슬라이싱 하지 않고 label로 슬라이싱 하는 경우, 마지막 라벨은 포함됩니다.

# %%
data = {'Country': ['Belgium', 'India', 'Brazil'],
        'Capital': ['Brussels', 'New Delhi', 'Brasília'],
        'Population': [11190846, 1303171035, 207847528]}

df_2 = pd.DataFrame(data
                  , index=['aa', 'bb', 'cc']                  
                 )

df_2
# Out:
#     Country    Capital  Population
# aa  Belgium   Brussels    11190846
# bb    India  New Delhi  1303171035
# cc   Brazil   Brasília   207847528

# %%
# label 슬라이싱. 'cc' 포함
df_2['aa':'cc']
# Out:
#     Country    Capital  Population
# aa  Belgium   Brussels    11190846
# bb    India  New Delhi  1303171035
# cc   Brazil   Brasília   207847528

# %% [markdown]
# ## 1) 인덱싱
#
# - loc (Label based indexing)
# - iloc (Positional indexing)
# - ix (사용 권장하지 않음)

# %%
df.iloc[0,0] # 위치를 통한 인덱싱
# Out:
# 'Belgium'

# %%
df.iat[0,0] # 위치를 통한 인덱싱
# Out:
# 'Belgium'

# %%
df.loc[0, 'Country'] # 라벨을 통한 인덱싱
# Out:
# 'Belgium'

# %%
df.at[0, 'Country'] # 라벨을 통한 인덱싱
# Out:
# 'Belgium'

# %%
df.ix[1, 'Capital'] # 위치/라벨을 통한 인덱싱 (사용하지 말것을 권장)
                    # 행은 위치, 열은 라벨을 통해 인덱싱
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-fc539d058a25> in <module>()
# ----> 1 df.ix[1, 'Capital'] # 위치/라벨을 통한 인덱싱 (사용하지 말것을 권장)
#       2                     # 행은 위치, 열은 라벨을 통해 인덱싱
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'

# %% [markdown]
# ## 2) 슬라이싱

# %%
df.iloc[0:1,0:2] # 위치를 통한 슬라이싱 (끝은 미포함)
# Out:
#    Country   Capital
# 0  Belgium  Brussels

# %%
df.loc[0:1, 'Country':'Capital'] # 라벨을 통한 슬라이싱 (끝 포함)
# Out:
#    Country    Capital
# 0  Belgium   Brussels
# 1    India  New Delhi

# %%
df.loc[0:1, 'Capital':'Country'] # 라벨의 순서를 역으로 하면, 아무런 값도 조회되지 않음
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1]

# %% [markdown]
# ## 3) 불리언 인덱싱 (필터링)
# - 조건을 제시하고 조건이 True인 요소만을 조회하는 방식
# - 필터링이라고도 불리웁니다.

# %%
df
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasília   207847528

# %%
df['Population'] > 200000000 # 조건 제시
# Out:
# 0    False
# 1     True
# 2     True
# Name: Population, dtype: bool

# %%
df[df['Population'] > 200000000] # 필터링 된 데이터만 조회
# Out:
#   Country    Capital  Population
# 1   India  New Delhi  1303171035
# 2  Brazil   Brasília   207847528

# %% [markdown]
# ## 실습

# %%
# dataframe
data = {
        'country': ['Belgium', 'France', 'Germany', 'Netherlands', 'United Kingdom'],
        'population': [11.3, 64.3, 81.3, 16.9, 64.9],
        'area': [30510, 671308, 357050, 41526, 244820],
        'capital': ['Brussels', 'Paris', 'Berlin', 'Amsterdam', 'London']
        }

countries = pd.DataFrame(data)
countries = countries.set_index('country') # 인덱스 지정

countries
# Out:
#                 population    area    capital
# country
# Belgium               11.3   30510   Brussels
# France                64.3  671308      Paris
# Germany               81.3  357050     Berlin
# Netherlands           16.9   41526  Amsterdam
# United Kingdom        64.9  244820     London

# %% [markdown]
# ---
#
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 인구밀도를 의미하는 `density` 칼럼을 추가하세요. (주의: 현재 'population' 칼럼은 10만 단위로 표기되어 있습니다)
#
# </div>

# %%
countries['density'] = countries['population']*1000000 / countries['area']
countries
# Out:
#                 population    area    capital     density
# country
# Belgium               11.3   30510   Brussels  370.370370
# France                64.3  671308      Paris   95.783158
# Germany               81.3  357050     Berlin  227.699202
# Netherlands           16.9   41526  Amsterdam  406.973944
# United Kingdom        64.9  244820     London  265.092721

# %%
# iloc를 이용한 방법 응용

countries['density_ver2'] = countries.iloc[:, 0]*1000000 / countries.iloc[:, 1]
countries
# Out:
#                 population    area    capital     density  density_ver2
# country
# Belgium               11.3   30510   Brussels  370.370370    370.370370
# France                64.3  671308      Paris   95.783158     95.783158
# Germany               81.3  357050     Berlin  227.699202    227.699202
# Netherlands           16.9   41526  Amsterdam  406.973944    406.973944
# United Kingdom        64.9  244820     London  265.092721    265.092721

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 인구밀도가 300을 초과하는 국가(country)의 수도(capital)과 인구(population)을 선택해주세요.
#
# </div>

# %%
countries.loc[countries['density'] > 300, ['capital', 'population']]
# Out:
#                capital  population
# country
# Belgium       Brussels        11.3
# Netherlands  Amsterdam        16.9

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 'density_ratio' 칼럼을 추가해주세요. (density_ratio = 인구밀도/평균 인구밀도)
# </div>

# %%
countries['density_ratio'] = countries['density'] / countries['density'].mean()
countries
# Out:
#                 population    area  ... density_ver2  density_ratio
# country                             ...
# Belgium               11.3   30510  ...   370.370370       1.355755
# France                64.3  671308  ...    95.783158       0.350618
# Germany               81.3  357050  ...   227.699202       0.833502
# Netherlands           16.9   41526  ...   406.973944       1.489744
# United Kingdom        64.9  244820  ...   265.092721       0.970382
#
# [5 rows x 6 columns]

# %%
countries['density_ratio'] = countries['density'] / (sum(countries['density']) / len(countries))
countries
# Out:
#                 population    area  ... density_ver2  density_ratio
# country                             ...
# Belgium               11.3   30510  ...   370.370370       1.355755
# France                64.3  671308  ...    95.783158       0.350618
# Germany               81.3  357050  ...   227.699202       0.833502
# Netherlands           16.9   41526  ...   406.973944       1.489744
# United Kingdom        64.9  244820  ...   265.092721       0.970382
#
# [5 rows x 6 columns]

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 영국(United Kingdom)의 수도(capital)를 'Cambridge'로 변경해주세요.
# </div>

# %%
countries.loc['United Kingdom', 'capital'] = 'Cambridge'
countries
# Out:
#                 population    area  ... density_ver2  density_ratio
# country                             ...
# Belgium               11.3   30510  ...   370.370370       1.355755
# France                64.3  671308  ...    95.783158       0.350618
# Germany               81.3  357050  ...   227.699202       0.833502
# Netherlands           16.9   41526  ...   406.973944       1.489744
# United Kingdom        64.9  244820  ...   265.092721       0.970382
#
# [5 rows x 6 columns]

# %%
# iloc를 이용한 방법 응용

countries.iloc[1, 2] = 'Lyon'
countries
# Out:
#                 population    area  ... density_ver2  density_ratio
# country                             ...
# Belgium               11.3   30510  ...   370.370370       1.355755
# France                64.3  671308  ...    95.783158       0.350618
# Germany               81.3  357050  ...   227.699202       0.833502
# Netherlands           16.9   41526  ...   406.973944       1.489744
# United Kingdom        64.9  244820  ...   265.092721       0.970382
#
# [5 rows x 6 columns]

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 인구 밀도가 100 초과, 300 미만인 국가들을 표시해주세요.
# </div>

# %%
cntrs = countries[countries['density'] > 100]
cntrs[cntrs['density'] < 300]
# Out:
#                 population    area  ... density_ver2  density_ratio
# country                             ...
# Germany               81.3  357050  ...   227.699202       0.833502
# United Kingdom        64.9  244820  ...   265.092721       0.970382
#
# [2 rows x 6 columns]

# %%
countries[ (countries['density'] > 100) & (countries['density'] < 300)]
# Out:
#                 population    area  ... density_ver2  density_ratio
# country                             ...
# Germany               81.3  357050  ...   227.699202       0.833502
# United Kingdom        64.9  244820  ...   265.092721       0.970382
#
# [2 rows x 6 columns]

# %% [markdown]
# ---

# %% [markdown]
# - 스트링 다루는 법

# %%
countries['capital'].str.len()
# Out:
# country
# Belgium           8
# France            4
# Germany           6
# Netherlands       9
# United Kingdom    9
# Name: capital, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 수도가 7글자 이상인 국가들을 표시해주세요. (힌트: string의 len( )를 사용하세요.)
# </div>

# %%
countries[countries['capital'].str.len() >= 7]
# Out:
#                 population    area  ... density_ver2  density_ratio
# country                             ...
# Belgium               11.3   30510  ...   370.370370       1.355755
# Netherlands           16.9   41526  ...   406.973944       1.489744
# United Kingdom        64.9  244820  ...   265.092721       0.970382
#
# [3 rows x 6 columns]

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 수도에 'am' 이 포함되는 국가들을 표시해주세요. (힌트: string의 contains( )를 사용하세요.)
# </div>

# %%
countries[countries['capital'].str.contains('am')]
# Out:
#                 population    area  ... density_ver2  density_ratio
# country                             ...
# Netherlands           16.9   41526  ...   406.973944       1.489744
# United Kingdom        64.9  244820  ...   265.092721       0.970382
#
# [2 rows x 6 columns]

# %% [markdown]
# # 5. 삭제

# %% [markdown]
# ## 1) Row(행) 삭제
#
#
# - axis=0
# - axis의 기본 값이 0이니 생략 가능

# %% [markdown]
# ### 단일 행 삭제

# %%
df.drop(1)
# Out:
#    Country   Capital  Population
# 0  Belgium  Brussels    11190846
# 2   Brazil  Brasília   207847528

# %% [markdown]
# ### 복수 행 삭제

# %%
df.drop([0,1])
# Out:
#   Country   Capital  Population
# 2  Brazil  Brasília   207847528

# %% [markdown]
# ## 2) Column(열) 삭제
#
# - axis=1

# %% [markdown]
# ### 단일 열 삭제

# %%
df.drop('Country', axis=1)
# Out:
#      Capital  Population
# 0   Brussels    11190846
# 1  New Delhi  1303171035
# 2   Brasília   207847528

# %% [markdown]
# ### 복수 열 삭제

# %%
df.drop(['Country', 'Population'], axis=1)
# Out:
#      Capital
# 0   Brussels
# 1  New Delhi
# 2   Brasília

# %% [markdown]
# ## 참조. Series 삭제

# %%
s
# Out:
# a    3
# b   -5
# c    7
# d    4
# dtype: int64

# %%
s.drop(['a', 'c'])
# s = s.drop(['a', 'c']) # 삭제한 결과를 사용하고 싶다면 다시 변수로 선언해주어야 한다
# Out:
# b   -5
# d    4
# dtype: int64

# %%
s
# Out:
# a    3
# b   -5
# c    7
# d    4
# dtype: int64

# %% [markdown]
# # 6. Pandas 함수

# %%
df
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasília   207847528

# %% [markdown]
# ##  데이터 탐색에 유용한 함수

# %%
df.describe() # 숫자 열에만 적용. 숫자열의 통계값과 최대최소값등을 보여줌
# Out:
#          Population
# count  3.000000e+00
# mean   5.074031e+08
# std    6.961346e+08
# min    1.119085e+07
# 25%    1.095192e+08
# 50%    2.078475e+08
# 75%    7.555093e+08
# max    1.303171e+09

# %%
df.head(2) # 초반 n행을 보여줌. default는 5
# df.head(n=2)
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035

# %%
df.tail()
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasília   207847528

# %%
df.sort_values('Population') # 오름차순 정렬
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 2   Brazil   Brasília   207847528
# 1    India  New Delhi  1303171035

# %%
df.sort_values('Population', ascending=False) # 내림차순 정렬
# Out:
#    Country    Capital  Population
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasília   207847528
# 0  Belgium   Brussels    11190846

# %%
df.isnull() # null값이 있는지 확인
# Out:
#    Country  Capital  Population
# 0    False    False       False
# 1    False    False       False
# 2    False    False       False

# %%
# column(열)별로 null값이 있는지 확인
df.isnull().any() # axis=0이 생략된 형태
# df.isnull().any(axis=0)
# Out:
# Country       False
# Capital       False
# Population    False
# dtype: bool

# %%
# row(행)별로 null값이 있는지 확인
df.isnull().any(axis=1)
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
# null값이 DataFrame내에 하나라도 있는지 확인
df.isnull().any().any()
# Out:
# False

# %%
df2 = df.copy()

# %%
df2
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasília   207847528

# %%
df2.loc[0, 'Population'] = None

# %%
df2
# Out:
#    Country    Capital    Population
# 0  Belgium   Brussels           NaN
# 1    India  New Delhi  1.303171e+09
# 2   Brazil   Brasília  2.078475e+08

# %%
df2.isnull().any()
# Out:
# Country       False
# Capital       False
# Population     True
# dtype: bool

# %% [markdown]
# ## aggregate 함수

# %%
df.count()
# Out:
# Country       3
# Capital       3
# Population    3
# dtype: int64

# %%
df.sum()
# Out:
# Country              BelgiumIndiaBrazil
# Capital       BrusselsNew DelhiBrasília
# Population                   1522209409
# dtype: object

# %%
df.min()
# Out:
# Country        Belgium
# Capital       Brasília
# Population    11190846
# dtype: object

# %%
df.max()
# Out:
# Country            India
# Capital        New Delhi
# Population    1303171035
# dtype: object

# %%
df.mean() # 숫자 열에만 적용
# Out:
# Population    5.074031e+08
# dtype: float64

# %%
df.median() # 숫자 열에만 적용
# Out:
# Population    207847528.0
# dtype: float64

# %% [markdown]
# ## 실습

# %%
# !wget -O 'titles.csv' https://docs.google.com/spreadsheets/d/1fiioUPMRurfE523yWGaRF3ckO-TUHu1AaIAI6Eo7Ti8/export?format=csv
# Out:
# --2021-01-21 01:58:34--  https://docs.google.com/spreadsheets/d/1fiioUPMRurfE523yWGaRF3ckO-TUHu1AaIAI6Eo7Ti8/export?format=csv
# Resolving docs.google.com (docs.google.com)... 74.125.20.138, 74.125.20.101, 74.125.20.139, ...
# Connecting to docs.google.com (docs.google.com)|74.125.20.138|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://doc-0c-7k-sheets.googleusercontent.com/export/l5l039s6ni5uumqbsj9o11lmdc/71mt87t6gge9077p6odifijg74/1611194310000/108232705785285457950/*/1fiioUPMRurfE523yWGaRF3ckO-TUHu1AaIAI6Eo7Ti8?format=csv [following]
# Warning: wildcards not supported in HTTP.
# --2021-01-21 01:58:34--  https://doc-0c-7k-sheets.googleusercontent.com/export/l5l039s6ni5uumqbsj9o11lmdc/71mt87t6gge9077p6odifijg74/1611194310000/108232705785285457950/*/1fiioUPMRurfE523yWGaRF3ckO-TUHu1AaIAI6Eo7Ti8?format=csv
# Resolving doc-0c-7k-sheets.googleusercontent.com (doc-0c-7k-sheets.googleusercontent.com)... 74.125.195.132, 2607:f8b0:400e:c09::84
# Connecting to doc-0c-7k-sheets.googleusercontent.com (doc-0c-7k-sheets.googleusercontent.com)|74.125.195.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/csv]
# Saving to: ‘titles.csv’
#
# titles.csv              [    <=>             ]   4.75M  7.85MB/s    in 0.6s
#
# 2021-01-21 01:58:37 (7.85 MB/s) - ‘titles.csv’ saved [4976033]

# %%
titles = pd.read_csv('titles.csv')
titles.head()
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1        Ashes of Kukulcan  2016
# 2  The Thousand Plane Raid  1969
# 3         Crucea de piatra  1993
# 4                   The 86  2015

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: titles 데이터프레임에는 몇 개의 영화가 기록되어 있나요?
# </div>

# %%
len(titles) # My answer
# Out:
# 215981

# %%
titles.count()
# Out:
# title    215981
# year     215981
# dtype: int64

# %%
titles.shape
# Out:
# (215981, 2)

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: titles에서 가장 빠른 시기에 제작된 영화 두 개를 표시하세요.
# </div>

# %%
titles.sort_values('year').head(2) # My answer
# Out:
#                                                     title  year
# 165182                                         Miss Jerry  1894
# 85708   Reproduction of the Corbett and Fitzsimmons Fight  1897

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 제목(title)이 "Hamlet"인 영화는 몇 개가 있나요?
# </div>

# %%
titles[titles['title'].str.contains('Hamlet')].count() # My answer
# Out:
# title    54
# year     54
# dtype: int64

# %%
titles[titles['title'] == 'Hamlet'].count() # My answer
# Out:
# title    19
# year     19
# dtype: int64

# %%
len(titles[titles['title'] == 'Hamlet'])
# Out:
# 19

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 제목(title)이 "Treasure Island"인 영화를 제작년도(year)의 오름차순에 따라 표시하세요. (df.sort_values())
# </div>

# %%
titles[titles['title'] == "Treasure Island"].sort_values('year') # My answer
# Out:
#                   title  year
# 191379  Treasure Island  1918
# 47769   Treasure Island  1920
# 192917  Treasure Island  1934
# 90175   Treasure Island  1950
# 104714  Treasure Island  1972
# 103646  Treasure Island  1973
# 190792  Treasure Island  1985
# 166675  Treasure Island  1999

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 1590년에서 1959년 사이 몇 개의 영화가 만들어졌나요?(1950 <= 제작년도 <= 1959)
# </div>

# %%
titles[(titles['year'] >= 1590) & (titles['year'] <= 1959)].count() # My answer
# Out:
# title    45489
# year     45489
# dtype: int64

# %%
len(titles[(titles['year'] >= 1590) & (titles['year'] <= 1959)]) # MYy answer
# Out:
# 45489

# %% [markdown]
# # 7. apply 함수
#
# - apply함수는 요소별로 적용됨

# %% [markdown]
# ## 하나의 요소를 활용하는 경우

# %%
df.loc[:, 'Population':'Population']

# %% [markdown]
# - 각 Population에 1씩 추가

# %%
df.loc[:, 'Population':'Population'].apply(lambda x: x + 1)

# %% [markdown]
# ## 여러개의 요소를 활용하는 경우

# %%
df.loc[:, 'Country':'Capital']

# %% [markdown]
# 칼럼명(Country, Capital)을 사용해도 되고 칼럼 위치(0, 1)를 사용해도 됩니다.

# %%
df.loc[:, 'Country':'Capital'].apply(lambda x: x['Country'] + "'s capital is " + x['Capital'], axis=1)

# %%
df.loc[:, 'Country':'Capital'].apply(lambda x: x[0] + "'s capital is " + x[1], axis=1)

# %% [markdown]
# # 8. GroupBy

# %% [markdown]
# dataframe을 key값에 따라 나눈 뒤 각각에 특정한 함수를 적용한 뒤 다시 합치고 싶을때 사용합니다.
#
# groupby는 Split-Apply-Combine 단계를 거칩니다.
#
# - **Split**: Key값에 따라 나눈 뒤
# - **Apply**: 함수를 적용
# - **Combine**: 다시 합치기
#
#
# SQL의 **GROUP BY**와 유사합니다.

# %% [markdown]
# ![alt text](https://github.com/jorisvandenbossche/pandas-tutorial/blob/master/img/splitApplyCombine.png?raw=true)

# %% [markdown]
# 아래 데이터로 Groupby 예를 들어 보겠습니다.

# %%
df = pd.DataFrame({'key':['A','B','C','A','B','C','A','B','C'],
                   'data': [0, 5, 10, 5, 10, 15, 10, 15, 20]})
df

# %% [markdown]
# key값에 따라 data의 합을 구하고 싶다면 어떻게 해야 할까요?
#
# key값대로 불리언인덱싱을 한 후 sum()함수를 취해주면 됩니다.

# %%
df['key'].unique()

# %% [markdown]
# key는 'A', 'B', 'C' 이렇게 세 개가 있고 각각의 키값에 대해 불리언 인덱싱을 한 후 sum()해보겠습니다.

# %%
df[df['key'] == "A"].sum()

# %%
df[df['key'] == "B"].sum()

# %%
df[df['key'] == "C"].sum()

# %% [markdown]
# 이 과정을 groupby를 사용하면 한번에 수행할 수 있습니다.

# %%
df.groupby('key').sum()
# df.groupby('key').aggregate(np.sum)  # 'sum'

# %% [markdown]
# ## 실습

# %%
df = pd.read_csv('https://raw.githubusercontent.com/jorisvandenbossche/pandas-tutorial/master/data/titanic.csv')

# %%
df.head()

# %% [markdown]
# 타이타닉 데이터셋을 df라는 판다스 데이터프레임으로 불러왔습니다. 이 데이터로 아래 실습을 진행해주세요.

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: groupby()를 사용하여 각 성별(sex)의 평균 나이(age)를 구하세요.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 전체 승객(passenger)의 평균 생존율을 구하세요.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 25세 이하 승객의 생존율을 구하세요. (힌트: 불리언 인덱싱)
# </div>

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 남성의 생존율을 구하세요. 여성의 생존율을 구하세요. (힌트: 불리언 인덱싱)
# </div>

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 생존율을 구하는 함수가 작성되어 있습니다. 성별 생존율을 groupby를 활용해 구하기 위해 ?부분을 알맞게 채워주세요.
# </div>

# %%
def survival_ratio(survived):
    return survived.sum() / len(survived)
  
df.groupby(?)[?].aggregate(survival_ratio)

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 'Pclass'별로 생존율을 보기 위해 bar 차트를 그리고자 합니다. ?부분을 알맞게 채워서 bar 차트를 그려주세요.
# </div>

# %%
df.groupby(?)[?].aggregate(survival_ratio).plot(kind='bar')
